# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import pandas as pd
import csv
import requests
import re

# %%
# 크롤링한 파일 저장 경로
file_path = 'C:\\Users\\HS\\Documents\\GitHub\\2018summerBoAZ\\homework\\3주차 과제'
file_name = 'result_example.csv'
page_num = []
star = []
review = []

for i in range(1,16):
    url ="http://deal.11st.co.kr/product/SellerProductDetail.tmall?method=getProductReviewList&prdNo=87595509&page="+str(i)+"&pageTypCd=first&reviewDispYn=Y&isPreview=false&reviewOptDispYn=n&optSearchBtnAndGraphLayer=n&reviewBottomBtn=Y&openDetailContents=Y&pageSize=10&isIgnoreAuth=false&lctgrNo=1001369&leafCtgrNo=0&groupProductNo=0&groupFirstViewPrdNo=0&selNo=16674487#this"
    url2 = urlopen(url)
    soup = BeautifulSoup(url2,"html.parser") 
    
    reviews = soup.find_all("a",{"id":"reviewContTxt"})
    p = re.compile('^selr_star selr_star')
    stars= soup.find_all("span", class_=p)
    star_list = [int(x.text[-2]) for x in stars]
    
    for ii in reviews:
        review.append(ii.text.strip())
        
    for jj in star_list:
        star.append(jj)
        page_num.append(i)

# %%
result = pd.DataFrame({'페이지': page_num, '별점': star, '리뷰': review})
result
# Out:
#      페이지  별점                                                 리뷰
# 0      1   5  네이처 사무용의자를 첨에 받았을 때 내가 과연 잘 조립할 수 있을까 걱정했는데 이게...
# 1      1   4  중저가 제품중에선 최상의 의자라고 생각합니다. 먼저 가장 중요한 뛰어난 가성비! 괜...
# 2      1   5  네이처 리얼 라텍스 의자 완전 대박ㅠㅠㅠ 너무 편해요!!! 첨엔 그냥 어차피 의자 ...
# 3      1   5  사무실 의자가 자꾸 소리도 나고 불편해져서 \n 녹색창에서 컴퓨터 의자를 검색하다가...
# 4      1   5  처음엔 좀 무겁다 느꼈지만 바닥 긁힘 전혀 없구요, 의자 쿠션 푹신하고 등받이 매쉬...
# 5      1   5  원래 비싸더라도 좋은브랜드 사려고햇엇는데 요의자 저렴하고 평도 좋고 많이들 사셔서 ...
# 6      1   5  총알배송이네여. 화요일 주문햐그 목요일에 받았네요 택배기사님 친절하셔서 감사했어요 ...
# 7      1   3  일단 배송이 빨라서 좋았습니다. 물건도 괜찮은거 같구요. 아쉬운점은 물건을 보니 부...
# 8      1   5  조립도 쉽고 의자도 편합니다. 가격대비 대만족합니다. 공구 없이 맨손으로도 조립할 ...
# 9      1   3  가격대비는 좋은듯하나 제품의 마감이 조금 별로네요 까진부분도 있고 등쪽 부품은 모서...
# 10     2   4  내게 딱 필요한 기능만 포함해서 구매할 수 있어서 좋았고 조립 간편했고 내구성은 나...
# 11     2   3  가격만 보고 사는 의자여! 가격치고는 트튼하고 간단하게 슬 수 있어. 가성비가 좋은...
# 12     2   1  택배 기사도 물건 그냥 던져놓고 가고 박스도 다 뜯어져서 왔습니다. 상품도 뜯어보니...
# 13     2   1  재질.마감.내구성은 보통 입니다. 문제는 기능이.. 의자 높이가 찔끔 조절됩니다.....
# 14     2   5  배송도 빠르고 가격대비 너무좋아요 등받이 쿠션은 성인한테는좋은데 12살 딸아이는 아...
# 15     2   4  배송은 주문한 다음 날 도착 상품의 상태는 특별한 이상없이 양호 설치는 꼽기만 하면...
# 16     2   5  가격대비 대만족합니다. 의자편하고 조립도 도구 필요없이 맨손으로 가능해서 좋습니다....
# 17     2   5  조립간단하고 제법튼튼합니다만 시디즈의 튼튼한 메쉬에비하면 등은 살짝부실한듯요 그래도...
# 18     2   3  반조립상태로 보내주셔서 설명서없이 1분안에조립했어요 등받이 젖힘,팔걷이는 견고하지 ...
# 19     2   3  등받이가 너무 약합니다 특히 등판이 좌우로 잘 못버텨요 6시방향은 버티는데 5시 7...
# 20     3   3  배송은 받은건 보통이고 박스가 찢어지기도 했는데 상품은 망가진곳은 없네여 상품도 금...
# 21     3   4  여름에 사용하기 시원하고 디자인 깔끔하고 싼 가격이라 불편하지 않을까 걱정햇는데 전...
# 22     3   5  조립 완전 쉽구요 2분걸린듯? 생각했던거보다 의자 훨씬 조아요 쿠션도 푹신하고 등받...
# 23     3   3  가격다운 품질이군요 검품도 엉망이고요 허리가 배기고 각부분연결이 나사 한개로 다 되...
# 24     3   5  그린색으로 샀다가 의자 넘넘 좋아서 핑크로 하나 더 샀어요 이번엔 조립 몇초만에 뚝...
# 25     3   1  오프라인 의자 대비 반값이라 샀건만.. 의자 균형도 안맞고 불편하네요. 하루종일 앉...
# 26     3   4  조립도 간편하고 배송도 빨라서 좋았습니다~ 생각보다 커서 방이 꽉차 보이지만 아이가...
# 27     3   5             조립은 쉬운데 프라스틱 제품이라서 받침대 내구성이 어쩔지 모르겠네요.
# 28     3   4  굉장히 택배가 빨리오고, 조립하기도 쉬워요! 등부분이 약간 흔들리는게 거슬리지만 좋...
# 29     3   4  배송이 하루도 안되서 완료^^ 플라스틱이 부러질까 걱정스럽기는 한데 편하다고하네요....
# ..   ...  ..                                                ...
# 120   13   5  11번가에서 물건을 여러개 동시에 주문하였는데 의자가 제일먼저 발송했다고 문자왔어요...
# 121   13   4  구매한지 얼마 되진 않았지만 가격 대비 의자의 견고함이나 내구성은 아직까지 느끼기에...
# 122   13   5  컴퓨터 앞에 30분만 앉아있어도 목이랑 어깨가… 특히 허리가 너무 아파서, 좀 가격...
# 123   13   5  집에서 사용하는 의자로 주문한 제품이예요~ 처음에는 간단하게 저렴한 제품으로 정할려...
# 124   13   5  포토리뷰는 처음 써보네요. 그만큼 마음에 들어서 써봅니다ㅋ [테이큰 완성형-그레이 ...
# 125   13   3  배송은 이상없이 왔습니다. 조립은 거의 그냥꽂으면 되는 수준입니다. 저가의자라 큰기...
# 126   13   2  약 1년 4개월 정도 사용하였는데요 의자 가죽이 완전 ㅜㅜㅜ 다 갈라졌어요. 의자를...
# 127   13   5  일단 배송 단 하루만에 왔구요 배송 하시는분도 무거우실텐데 매우 친절하시더라구요 그...
# 128   13   4  사실 듀오백이니 허리 받침 의자니 하는 이름이 붙기 시작하면서 의자들의 가격은 기본...
# 129   13   5  저는 30대중반의 회사원입니다. 집에와서도 일을 해야 하기에 의자를 신경써서 바꾸었...
# 130   14   5  안녕하세요? 최근 마이홈 의자(모델명=3026[주니온]완성형+대요추+헤드,색상선택:...
# 131   14   5  컴퓨터 사면서 의자 책상구입하눈데 따로구입하느라 애먹었네여 같이 팔면좋을텐데.. 배...
# 132   14   5  친절문자까지 주시고... 조립도 그다지 어렵지 않고요. 아주 쉽습니다^^ 어디 몇군...
# 133   14   5  독서실 다니다가 이제 여름이라 날씨가 덥거나 비오거나 둘 중 하나일것같고...집이랑...
# 134   14   5  솔직히~ 의자업계 1위라는 광고를 보고 혹해서 구입하긴 하였습니다. 그런데 의자 업...
# 135   14   2  상품 수령후 조립하다보니 다리에 작은 스크래치가 있었지만 인테리어 소품도 아니고상관...
# 136   14   5  지금 사용하던 의자 등받이가 분리가 돼서 자꾸 양옆, 앞뒤로 움직이는 바람에 장시간...
# 137   14   5  한달 앉아보고 리뷰쓰려다가 너무 맘에들어서 일주일만에 리뷰씁니다 ㅎ 첨에 싼 의자를...
# 138   14   5  6/7에 시켰는데 9일 토요일 낮에 왔어요. 이정도면 배송일은 무난하네요~ 이런 큰...
# 139   14   5  매우 만족스러운 의자구매 후 나름대로 제품에 대한 평가를 해봅니다. 몇 시간을 들여...
# 140   15   5  의자가 부서졌었습니다... 그래서 새로운 의자를 마련하고자 찾다가 11번가에서 마이...
# 141   15   5  제가 인터넷에서 물건사고 구매확정 해본 적이 첨 인것 같아요 ㅎㅎ 연구실에 매일 너...
# 142   15   4  11번가에서 주문한 마이홈의자 주니온 완성형. 메쉬가 통풍 잘 되고 시원하다곤 들었...
# 143   15   3  전에도 한번 구매했던 제품이라 믿고 구매했는데 헤드레스트를 빼고 보내주셨네요ㅠ 헤드...
# 144   15   5  정말 만족하고 사용하고있습니다 지난20년간 앉아왔던 딱딱한 우드소재 의자는 재활용 ...
# 145   15   5  일단 받아보니 조립하기 쉽게 낱개 포장이 잘 되어 있었어요. 봐도 어찌 조립해야할지...
# 146   15   5  일단 배송은 빠른편이예요~ 입금하고 3일만에 받았구요 처음엔 투박해보이고 무거워보였...
# 147   15   5  주문 하루만에박스포장으로 흠없이 무사히 배송 받았습니다. 일단, 산뜻한 색상이 눈에...
# 148   15   5  책상이 유럽제라, 여기에 어울릴만한 의자를 찾다보니, 요추건강에 좋지 않은 디자인뿐...
# 149   15   5  1주일간 써보니 적당히 뒤로 기울며 등과 허리를 받쳐주는 기능이 일반적인 저렴한 의...
#
# [150 rows x 3 columns]

# %%
result.to_csv(file_path+file_name, encoding = 'utf-8')
